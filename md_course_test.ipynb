# %%
import sys
print(sys.executable)
# Out:
# c:\Users\lenovo\miniconda3\envs\md-course\python.exe

# %%
import numpy as np
import scipy
import matplotlib
import pandas as pd
import mdtraj
import openmm

print("NumPy:", np.__version__)
print("SciPy:", scipy.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Pandas:", pd.__version__)
print("MDTraj:", mdtraj.__version__)
print("OpenMM:", openmm.__version__)
# Out:
# NumPy: 2.5.0
# SciPy: 1.18.0
# Matplotlib: 3.10.9
# Pandas: 2.3.3
# MDTraj: 1.11.1
# OpenMM: 8.5.2

# %%
import sys

print("Python executable:")
print(sys.executable)
print()

print("Python version:")
print(sys.version)
# Out:
# Python executable:
# c:\Users\lenovo\miniconda3\envs\md-course\python.exe
#
# Python version:
# 3.12.13 | packaged by Anaconda, Inc. | (main, Mar 19 2026, 20:16:45) [MSC v.1942 64 bit (AMD64)]

# %%
print("Test change")
# Out:
# Test change
